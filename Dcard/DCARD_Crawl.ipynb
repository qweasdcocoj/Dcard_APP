# %%
print(123)
# Out:
# 123

# %%
# 載入使用的套件
import pandas as pd
import requests
from requests_html import HTML
import re


# 檢視資料結構
def Crawl(ID):
    url = 'https://www.dcard.tw/_api/posts/' + ID
# 透過request套件抓下這個網址的資料
    requ = requests.get(url)
# 初步檢視抓到的資料結構
    requ.json()
    rejs=requ.json()
    return(pd.DataFrame(
        data=
        [{'ID':rejs['id'],
          'title':rejs['title'],
          'content':rejs['content'],
          'excerpt':rejs['excerpt'],
          'createdAt':rejs['createdAt'],
          'updatedAt':rejs['updatedAt'],
          'commentCount':rejs['commentCount'],
          'forumName':rejs['forumName'],
          'forumAlias':rejs['forumAlias'],
          'gender':rejs['gender'],
          'likeCount':rejs['likeCount'],
          'reactions':rejs['reactions'],
          'topics':rejs['topics']}],
        columns=['ID','title','content','excerpt','createdAt','updatedAt','commentCount','forumName','forumAlias','gender','likeCount','reactions','topics']))
# 撰寫簡單的函數，透過輸入文章ID，就輸出文章的資料
Crawl('231030181')
# Out:
#           ID    title                                            content  \
# 0  231030181  警察閃光get  首先謝謝大家對我媽的愛戴，但是目前警察閃光get 的呼聲比較多，所以睡不著的我趕快來交作業😎...
#
#                                              excerpt  \
# 0  首先謝謝大家對我媽的愛戴，但是目前警察閃光get 的呼聲比較多，所以睡不著的我趕快來交作業，...
#
#                   createdAt                 updatedAt  commentCount forumName  \
# 0  2019-04-05T17:28:38.734Z  2019-04-07T04:37:15.476Z            27        有趣
#
#   forumAlias gender  likeCount  \
# 0      funny      F        700
#
#                                            reactions         topics
# 0  [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03'...  [警察閃光get, 感情]

# %%
# 檢視資料結構
def Crawl_100(ID):
    url = 'https://www.dcard.tw/_api/posts/' + ID
# 透過request套件抓下這個網址的資料
    requ = requests.get(url)
# 初步檢視抓到的資料結構
    requ.json()
    rejs=requ.json()
    return(pd.DataFrame(
        data=
        [{'ID':rejs['id'],
          'title':rejs['title'],
          'content':rejs['content'],
          'excerpt':rejs['excerpt'],
          'createdAt':rejs['createdAt'],
          'updatedAt':rejs['updatedAt'],
          'commentCount':rejs['commentCount'],
          'forumName':rejs['forumName'],
          'forumAlias':rejs['forumAlias'],
          'gender':rejs['gender'],
          'likeCount':rejs['likeCount'],
          'reactions':rejs['reactions'],
          'topics':rejs['topics']}],
        columns=['ID','title','content','excerpt','createdAt','updatedAt','commentCount','forumName','forumAlias','gender','likeCount','reactions','topics']))
# Out:
# method

# %%
url = 'https://www.dcard.tw/_api/posts?popular=true&limit=100'
resq = requests.get(url)
rejs = resq.json()
df = pd.DataFrame()
for i in range(len(rejs)):
    df = df.append(Crawl(str(rejs[i]['id'])),ignore_index=True)
df
# Out:
# (100, 13)
#            ID                               title  \
# 0   233286891                             陳時中我拜託你
# 1   233291504                              我的男友約炮
# 2   233290769                        這世界很煩，但你要很可愛
# 3   233290828                              對不起 牙籤
# 4   233288949                      這個時候 我希望我不是護理師
# ..        ...                                 ...
# 95  233289782  防疫期間～去不成..國，那就到苗栗國旅行吧٩(˃̶͈̀௰˂̶͈́)و
# 96  233293393                               穿搭不穿搭
# 97  233287154                              被掰歪的我😳
# 98  233288808                         面對霸凌你就是要硬起來
# 99  233287936                       （圖文）我以為是豔遇😭😭😭
#
#                                               content  \
# 0   部長大人⋯小弟在這請求你\n上班八小時就好 好好的休息\n防疫是一個長期的抗爭\n我一起床 ...
# 1   更\n謝謝所有給我安慰的人\n早上一睜開眼就痛苦得流淚⋯\n一個晚上醒來好幾次一直夢見他\n...
# 2   最近看完這本書《這世界很煩，但你要很可愛》\n猶記剛步入社會開始上班的樣子\n每天用心打扮自...
# 99  2020-03-18T06:10:53.214Z  2020-03-18T07:29:11.963Z            14
#
#    forumName    forumAlias gender  likeCount  \
# 0       武漢肺炎     2019_ncov      M      33739
# 1         感情  relationship      F      12741
# 2         美妝        makeup      F       8961
# 3         有趣         funny      F       7334
# 4       武漢肺炎     2019_ncov      F       6872
# ..       ...           ...    ...        ...
# 95        旅遊        travel      F        271
# 96        穿搭       dressup      M        282
# 97        彩虹       rainbow      F        265
# 98        心情          mood      F        271
# 99        有趣         funny      F        261
#
#                                             reactions  \
# 0   [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03'...
# 1   [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03'...
# 2   [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03'...
# 3   [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03'...
# 4   [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03'...
# ..                                                ...
# 95  [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03'...
# 96  [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03'...
# 97  [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03'...
# 98  [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03'...
# 99  [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03'...
#
#                          topics
# 0                            []
# 1              [分手, 感情, 偷吃, 約炮]
# 2                        [妝容分享]
# 3                            []
# 4        [武漢肺炎, 護理, 時事, 肺炎, 醫護]
# ..                          ...
# 95        [苗栗, 自由行, 旅遊, 遊記, 景點]
# 96                         [穿搭]
# 97                [彩虹, 幸福, 小故事]
# 98                         [霸凌]
# 99  [怕爆, 武漢肺炎, 口罩, 散播病毒散播愛, 傻眼]
#
# [100 rows x 13 columns]

# %%
for j in range(9):
    last = str(int(df.tail(1).ID)) # 找出爬出資料的最後一筆ID
    url = 'https://www.dcard.tw/_api/posts?popular=true&limit=100&before=' + last
    resq = requests.get(url)
    rejs = resq.json()
    for i in range(len(rejs)):
        df = df.append(Crawl(str(rejs[i]['id'])), ignore_index=True)
print(df.shape)
df
# Out:
# <Response [403]>
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-27-6c77543640a5> in <module>
#       4     resq = requests.get(url)
#       5     print(resq)
# ----> 6     rejs = resq.json()
#       7     for i in range(len(rejs)):
#       8         df = df.append(Crawl(str(rejs[i]['id'])), ignore_index=True)
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
df.to_excel('C:/Users/Tsai/Dcard/Dcard_hot100.xlsx')
# Out:
# C:\Users\Tsai\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:937: UserWarning: Ignoring URL 'https://giftbox.dcard.tw/groupBuy/5e6b510d8cf3cc189a11eadf/header?isWebView=true&webGestureFirst=true
#
#
# Hi%20我是好物研究員，不夠抗痘不推薦🎁
# 守護火種錢包是我的使命，堅持尋找好物是給你們的承諾！
#
# 你，
# 擦了許多瓶瓶罐罐，肌膚卻無法吸收？
# 你以為你的肌膚難題，手邊的面膜能解決?
# 浪費15分鐘，卻沒什麼水潤保濕的感覺☹️
# 或者，
# 你也有擾人的痘痘困擾，
# 那麼跟著研究員繼續看下去吧～
#
# https://i.imgur.com/ypcMWQW.jpg
# 今天！所有的商品都是升級再升級的2.0🌟
# 添加了VitaBtech™獨特成分
# 以水嫩、修護、光澤、舒緩、彈力為基礎，
# 結合了Bio生物研發科技，在數十種維他命中，精選出肌膚最需要的B群，
# 建構出剔透水嫩的基礎膚況，提供肌膚全方位功效。
#
# 我想啊～痘痘大概是人生不管什麼時候都遇的到的敵人，
# 所以研究員來介紹神奇的抗痘3寶🥳
# 讓你洗、拍、抹。
# 控油+補水平衡三步驟，成為痘痘大剋星☄️
# 全系列添加「柳蘭精萃」為非類固醇類的抗發炎成分，
# 能提高肌膚的含水量、修護肌膚不適、改善肌膚暗沉、
# 注入熊果素、維生素B3，提高皮膚的白嫩度🧚🏻‍♀️提升澎彈力與光澤感
#
# 你說你不相信是不是？
# 那你就買買看呀(ﾟ3ﾟ)～♪
# 自己來實驗，再來跟研究員分享你的心得
#
# 🌱微晶3D全能精華
#
# https://i.imgur.com/BhiCWGR.jpg
# 熱銷十年，品牌經典不敗的神商品🏆
# 沒有神隊友也該擁有的神商品
# ✅不管什麼肌膚，都應該適時的加強肌膚的保濕機能。
# ✅每天使用，增強肌膚屏障，穩定肌膚狀況。
#
# 晚上薄塗當一般乳霜保養，
# 也能全臉厚敷當晚安面膜。
# 唇炎發作唇周乾燥脫皮紅腫疼痛，
# 也可以擦全能精華舒緩，再厚塗護唇膏啊～
# 他根本是萬用的精華💃🏻
#
# 研究員痘痘實驗室👩🏻‍🔬
# https://i.imgur.com/usIRP3L.jpg
# 痘痘肌同事試用了2天的抗痘3寶後，
# 泛紅跟痘痘膿腫的部分有明顯的消失！
# 用起來保濕不緊繃還感受到肌膚有增加保水度💦
# 讓原本的油肌達到油水平衡，
# 雖然這是抗痘的產品但洗完卻一點也不！緊！繃！
# https://i.imgur.com/ttwjAfF.jpg
# 看到這邊你如果還不相信他到底多神奇的話，
# 真的母湯，
# 人人都會長痘痘，但是卻沒有神器，
# 看到這篇算你賺到惹啦😂
#
# 【商品資訊】%20下滑B1%20
#
# 🛒🛒此次產品加入購物車🛒🛒
# 火種價：
# 🎈控油調理三步驟超值組(升級版抗痘菁露+升級版抗痘精華+升級版抗痘潔面乳)%20NTD%201980元
# 🎈萌萌菌修護調理潔淨組(微晶3D全能洗顏霜*3+萌萌菌奇肌面膜*3)%20NTD%201680元
# 🎈控油修護潔顏組(升級版抗痘精華+升級版抗痘潔面乳)%20NTD%201399元
# 🎈微晶3D全能基礎保養組(微晶3D全能洗顏霜+微晶3D全能精華)%20NTD%201399元
# 🎈控油調理潔顏組(升級版抗痘菁露+升級版抗痘潔面乳)%20NTD%20999元
# 🎈薇佳洗顏雙星組(微晶3D全能洗顏霜+升級版抗痘潔面乳)%20NTD%20780元
# 🎈微晶3D全能升級版洗顏霜%20NTD%20399元
#
# 💡好物研究室的諮詢管道：
# ecservice@dcard.cc若有訂單及商品問題，
# 請來信找研究員並附上訂單編號或是收件手機號碼唷！
# 如果想許願也可以寫信給我們喔❤️
# 研究員回覆時間✍️週一至週五%2010:00-18:00
#
# ❤️好物研究室官方%20IG❤️
# https://pse.is/PEGLE
# 會不定時舉辦限時抽獎活動並介紹各式新商品
# 還有各種你想不到有趣、新奇的貼文歡迎小火種們追起來！
# 來跟研究員互動唷！
# 如果想許願的話歡迎私訊給我們喔！
# https://i.imgur.com/cv2P3Qj.jpg' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLS
#   (force_unicode(url), max_url))
